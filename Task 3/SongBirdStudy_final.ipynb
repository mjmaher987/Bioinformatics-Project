# %% [markdown]
# # Final Project of Introduction to Bioinformatics
#
# ## The Song Bird Study

# %% [markdown]
# <div style="text-align: center;">
#     <img src="SocialNetworking.png" width="350">
# </div>

# %% [markdown]
# ### Introduction
#
# #### Investigating the Influence of Social Environment on Neural Responses to Sickness in Zebra Finches: A Bioinformatics Approach
#
# The Zebra Finch, _Taeniopygia guttata_, a widely used model organism in behavioral and neurobiological research, provides an excellent platform to study the interplay between social environment, neural function, and immune response. In this project, we delve into an intriguing scientific question: How does the social environment of these birds modulate their neural response to immune challenges?
#
# This question was explored in a study by Lopes PC, Faber-Hammond JJ, Siemonsma C, Patel S, and Renn SCP, titled _"The social environment alters neural responses to a lipopolysaccharide challenge"_ (Brain Behav Immun 2023). Their research demonstrated that the social environment, particularly the presence of conspecifics, could significantly modulate the neural responses of Zebra Finches to immune challenges such as lipopolysaccharide (LPS), a molecule known to induce immune responses. Link to Paper
#
# Our goal in this notebook is to revisit and build upon the findings of this study. Using RNA sequencing data from their research, we aim to conduct a comprehensive analysis of changes in gene expression across different brain regions of Zebra Finches under different social conditions. We will specifically focus on the hypothalamus, the bed nucleus of the stria terminalis, and the nucleus taeniae, all of which are key regions for understanding behavior and immune response.
#
# The essence of this project is to draw meaningful insights from high-dimensional data. We encourage you to start with basic approaches and gradually build complexity. Remember, every effort to extract information and gain insights from the data is valuable and will be recognized. Approach the tasks with curiosity and an open mind, and let your analytical journey be both informative and enjoyable.
#
# ---

# %% [markdown]
# ### Experiment Design
#
# The primary aim of this high-throughput sequencing study was to discern how different social environments could modulate the neural response to sickness induced by lipopolysaccharide (LPS).
#
# **Lipopolysaccharide (LPS)** is a large molecule consisting of a lipid and a polysaccharide, found in the outer membrane of Gram-negative bacteria. It is often referred to as an endotoxin due to its ability to trigger strong immune responses. When a Gram-negative bacterium dies, it releases its LPS, which can then find its way into the bloodstream. In the context of this study, LPS was used to simulate an immune challenge or sickness in the Zebra Finches.
#
# **The Experimental Setup:**
#
# The experiment involved male Zebra Finches, which were administered either an LPS injection to simulate sickness or a control solution. Following the injection, the birds were placed in one of four distinct social contexts:
#
# - **Isolated (ISO)**: In this setting, the birds were kept alone without a female. This condition was designed to examine the neural and immune responses of the birds in the absence of any social interactions. This group helps to understand the baseline responses to the LPS challenge when there are no social factors at play.
# - **Known Female Continuous (KFC)**: Here, the birds were continuously housed with a known female. This condition allowed the researchers to investigate the effects of a stable social environment on the birds' responses to the LPS challenge. This group can provide insights into how ongoing social interactions might influence the response to sickness.
# - **Known Female Reunited (KF)**: In this scenario, the birds were reunited with a known female after a period of separation. This condition was intended to mimic the effects of a disrupted social environment followed by a reunion. This group can shed light on how changes in social relationships might affect the neural and immune responses to sickness.
# - **Novel Female (NF)**: In this context, the birds were paired with a previously unknown female. This condition was designed to explore the effects of introducing a new social partner on the birds' responses to the LPS challenge. This group can reveal how novel social encounters might modulate the response to sickness.
#
# These social settings were carefully chosen to represent a range of social interactions that the birds might encounter in their natural habitats. The experimental design allows for a comprehensive investigation of how social environment influences the neural responses to sickness, thereby improving our understanding of how the social environment can affect health.
#
# ---

# %% [markdown]
# ### Understanding RNA-Seq
#
# RNA-Seq (RNA sequencing) is a powerful technique that uses next-generation sequencing (NGS) to reveal the presence and quantity of RNA molecules in a biological sample. It provides a snapshot of gene expression, also known as the transcriptome.
#
# **What is RNA-Seq?**
#
# RNA-Seq allows us to investigate and discover the transcriptome, which is the total cellular content of RNAs including mRNA, rRNA, and tRNA. Understanding the transcriptome is key if we are to connect the information in our genome with its functional protein expression. RNA-Seq can tell us which genes are turned on in a cell, what their level of transcription is, and at what times they are activated or shut off. This allows scientists to understand the biology of a cell more deeply and assess changes that may indicate disease.
#
# **How does RNA-Seq work?**
#
# The RNA-Seq workflow has several steps:
#
# 1. **RNA extraction**: The first step involves extracting the total RNA from the sample.
# 2. **Reverse transcription into cDNA**: The extracted RNA is then converted into complementary DNA (cDNA) through a process called reverse transcription.
# 3. **Library preparation**: The cDNA is then used to prepare a sequencing library. This involves fragmenting the cDNA, adding sequencing adapters, and amplifying the library.
# 4. **Sequencing**: The prepared library is then sequenced using high-throughput sequencing technology.
#
# **RNA-Seq Data**
#
# The output of an RNA-Seq experiment is a large set of short DNA sequences, or reads. These reads can be aligned to a reference genome to determine which genes were being transcribed at the time the sample was collected. The number of reads aligning to a particular gene provides a measure of that gene's expression level.
#
# **RNA-Seq vs Microarrays**
#
# RNA-Seq has several advantages over microarray technology, a legacy technology often used in gene expression studies. Unlike microarrays, which require species- or transcript-specific probes, RNA-Seq does not require any prior knowledge about the sequences of the transcripts. This allows RNA-Seq to detect novel transcripts, gene fusions, single nucleotide variants, indels (small insertions and deletions), and other previously unknown changes. RNA-Seq also has a wider dynamic range and higher sensitivity compared to microarrays, making it better at detecting transcripts and specifically isoforms.
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer these questions!</strong>
# </blockquote>
#
# **Questions**
#
# 1. Why is it important to convert RNA into cDNA for RNA-Seq? What would happen if we tried to sequence RNA directly?
# 2. How does the process of preparing a sequencing library contribute to the accuracy of RNA-Seq results? What are some potential sources of error in this step?
# 3. How does the ability of RNA-Seq to detect novel transcripts contribute to our understanding of gene function? Can you think of a scenario where this capability would be particularly useful?
# 4. Why might a researcher choose to use RNA-Seq instead of microarrays for a gene expression study? What are some potential advantages and disadvantages of each method?
#
#
# **_Your Answer:_**:
#
# ---

# %% [markdown]
# Q1) Why is it important to convert RNA into cDNA for RNA-Seq? What would happen if we tried to sequence RNA directly?
#
# 1. Compatibility with Sequencing Technologies: Most sequencing platforms are designed to read DNA, not RNA. By converting RNA to cDNA, we can use the same equipment and methods that are already established for DNA sequencing. RNA has different types and modifications that require different protocols and adapters for sequencing, such as mRNA, miRNA, tRNA, rRNA, and others
# 2. Stability: RNA is highly reactive and can degrade quickly under certain conditions. Converting RNA to cDNA stabilizes the RNA molecules, allowing them to be stored and processed without degradation.
# 3. Preservation of Information: The process of reverse transcription ensures that the information contained in the RNA molecule is preserved in the cDNA. This includes the sequence of the RNA, which is complementary to the DNA strand. RNA has a lower concentration and diversity than DNA in most cells, making it harder to obtain enough material for sequencing
# 4. Scalability: The ability to scale up the production of cDNA makes it easier to perform high-throughput sequencing, which is essential for analyzing large datasets generated by RNA-Seq experiments. RNA has secondary and tertiary structures that can interfere with the sequencing process and affect the accuracy and quality of the reads

# %% [markdown]
# Q2) How does the process of preparing a sequencing library contribute to the accuracy of RNA-Seq results? What are some potential sources of error in this step?
#
# 1. Consistency: A well-prepared library ensures that all samples have the same starting material and conditions, which helps maintain consistency across all samples. RNA extraction and purification: The methods and kits used for isolating and purifying RNA from the biological samples can affect the yield, integrity, and representation of the RNA molecules. For example, some methods may preferentially enrich or deplete certain types or sizes of RNA, such as mRNA, miRNA, rRNA, or degraded RNA
# 2. Amplification: The library preparation step typically involves PCR amplification, which increases the number of copies of each cDNA fragment. This amplification is necessary to generate enough material for sequencing while still maintaining the quality of the reads. The methods and primers used for amplifying the cDNA library can affect the quantity, quality, and representation of the library. For example, some methods may introduce PCR bias, errors, artifacts, or duplicates.
# 3. Fragmentation: Fragmentation of the cDNA into smaller pieces is done to create a library suitable for sequencing. This fragmentation process can introduce errors if not done carefully, such as over-digestion or uneven fragmentation. The methods and conditions used for fragmenting RNA into smaller pieces can affect the distribution, length, and quality of the fragments. For example, some methods may introduce random or sequence-specific breaks, or cause damage to the RNA ends
# 4. Adapters: Sequencing adapters are added to the cDNA fragments to facilitate the attachment of sequencing primers. Poor quality or incorrect adapters can lead to low-quality reads or failed sequencing. The methods and adapters used for attaching synthetic oligonucleotides to the cDNA ends can affect the complexity, diversity, and uniformity of the library. For example, some methods may introduce ligation bias, adapter dimers, or chimeric molecules.
# 5. Quality Control: The library preparation process should include quality control checks, such as checking for contamination, verifying the integrity of the cDNA, and assessing the yield and purity of the library.
#
#
# Potential sources of error in the library preparation step include:
# 1. Contamination: Cross-contamination between samples or between cDNA and other materials can occur during the preparation process.
# 2. Over-digestion: Over-digestion of the cDNA can result in fragments that are too small to be reliably sequenced.
# 3. Uneven fragmentation: If the cDNA is not evenly fragmented, some fragments may be too long or too short, leading to poor representation in the sequencing data.
# 4. Adapter contamination: Adapters that are not properly attached to the cDNA fragments can lead to misaligned reads or failed sequencing.
# 5. PCR inefficiencies: Inefficient PCR amplification can result in low yields or non-uniform amplification, affecting the depth of coverage and the quality of the sequencing data.
# 6. Incomplete reverse transcription: If the reverse transcription process is not complete, some RNA molecules may not be converted into cDNA, leading to incomplete coverage of the transcriptome.

# %% [markdown]
# Q3) How does the ability of RNA-Seq to detect novel transcripts contribute to our understanding of gene function? Can you think of a scenario where this capability would be particularly useful?
#
# 1. Discovery of Alternative Splicing: RNA-Seq can identify multiple transcripts originating from a single gene due to alternative splicing. This allows researchers to explore the complexity of gene regulation and the diversity of protein products that can be produced from a single gene.
# 2. Identification of Gene Fusions: RNA-Seq can detect gene fusions, where two genes are joined together, resulting in a single transcript. This is particularly relevant in cancer research, where gene fusions can drive tumor growth and resistance to therapy.
# 3. Uncovering Non-Coding RNAs: RNA-Seq can reveal non-coding RNAs, which play roles in gene regulation, development, and other cellular processes. These RNAs can influence gene expression without coding for proteins themselves.
# 4. Understanding Cellular Diversity: The discovery of novel transcripts can help explain the diversity within a population of cells, such as different cell types or states within a single cell type.
# 5. Epigenetic Regulation: RNA-Seq can show how epigenetic modifications, such as methylation or histone modification, affect gene expression by revealing novel transcripts that are regulated differently.
# 6. Pathogenesis Studies: In diseases, RNA-Seq can uncover novel transcripts associated with disease pathways, providing insights into the underlying mechanisms.
#
# A scenario where detecting novel transcripts would be particularly useful is in the study of cancer. Cancer is a complex and heterogeneous disease that is characterized by genomic and transcriptomic alterations that affect gene function and cellular behavior5. RNA-Seq can help identify novel transcripts that are associated with cancer development, progression, or response to treatment, such as:
#
# Fusion genes that result from chromosomal rearrangements and produce chimeric proteins with oncogenic or drug-resistant properties.
# Alternative splicing events that generate isoforms with different functions, interactions, or localizations that affect cell growth, survival, or invasion.
# Non-coding RNAs that regulate gene expression or splicing at various levels, such as miRNAs, lncRNAs, or circular RNAs.
# Therefore, RNA-Seq can provide valuable insights into the molecular mechanisms and biomarkers of cancer, and facilitate the development of novel diagnostic, prognostic, or therapeutic strategies.

# %% [markdown]
# Q4) Why might a researcher choose to use RNA-Seq instead of microarrays for a gene expression study? What are some potential advantages and disadvantages of each method?
#
# Advantages of RNA-Seq:
#
# 1. High Resolution: RNA-Seq provides a higher resolution of gene expression levels, allowing for the detection of subtle differences in expression that might be missed with microarrays.
# 2. Dynamic Range: RNA-Seq has a wider dynamic range, meaning it can detect both very low and very high levels of gene expression.
# 3. Non-Specific Probes Not Required: Unlike microarrays, which require species- or transcript-specific probes, RNA-Seq does not require any prior knowledge about the sequences of the transcripts. This allows RNA-Seq to detect novel transcripts and gene fusions.
# 4. Better Normalization: RNA-Seq data can be normalized more accurately, taking into account the length of the transcripts and the complexity of the RNA molecules.
# 5. More Isoform Specificity: RNA-Seq can distinguish between different isoforms of a gene, which is important for understanding the functional consequences of gene expression
#
# Disadvantages of RNA-Seq:
#
# 1. Cost: RNA-Seq is generally more expensive than microarrays due to the cost of sequencing and subsequent data analysis.
# 2. Complexity: The data analysis for RNA-Seq is more complex and requires specialized bioinformatics tools and expertise.
# 3. Time Consuming: The process of converting RNA to cDNA, library preparation, and sequencing can take longer than microarray analysis.
# 4. Data Volume: RNA-Seq generates a large amount of data, which can be challenging to manage and interpret.

# %% [markdown]
# ### Step 0: Installing Necessary Packages

# %%
import sys
import subprocess
import pkg_resources

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

REQUIRED_PACKAGES = [
    'biopython',
    'pandas',
    'numpy',
    'matplotlib',
    'seaborn',
    'xlrd',
    'mygene'
]

for package in REQUIRED_PACKAGES:
    try:
        dist = pkg_resources.get_distribution(package)
        print('{} ({}) is installed'.format(dist.key, dist.version))
    except pkg_resources.DistributionNotFound:
        print('{} is NOT installed'.format(package))
        install(package)
        print('{} was successfully installed.'.format(package))
# Out:
# biopython is NOT installed
# biopython was successfully installed.
# pandas (1.5.3) is installed
# numpy (1.23.5) is installed
# matplotlib (3.7.1) is installed
# seaborn (0.13.1) is installed
# xlrd (2.0.1) is installed
# mygene is NOT installed
# mygene was successfully installed.

# %%
# Import necessary libraries.
import pandas as pd
import numpy as np
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Loading the Dataset: A First Glimpse into the Zebra Finch's World
#
# With our tools at the ready, let's embark on the initial phase of our exploration. We'll load the dataset containing the read counts from the Zebra Finch RNA-Seq study and begin to unravel the secrets it holds.

# %%
# Loading the RNA-Seq read count data /content/drive/MyDrive/32386b5ca32140d3847c62905617d376.PDF
dataset_path = '/content/drive/MyDrive/GSE203528_readcount.xls'
df_read_counts = pd.read_csv(dataset_path, sep='\t')


display(df_read_counts.head())
# Out:
#                geneID  HY3  HY4  HY5  HY6  HY8  HY9  HY12  HY13  HY14  ...  \
# 0  ENSTGUG00000008284  145  113  149  121  159  172   133   153   192  ...
# 1  ENSTGUG00000003938   25   18   21   29   22   38    23    34    35  ...
# 2  ENSTGUG00000011987  915  681  938  638  900  749   736   717   657  ...
# 3  ENSTGUG00000017592    5    5    5   14    5    4    22    13    11  ...
# 4  ENSTGUG00000009442  226  211  221  257  202  197   231   201   263  ...
#
#    TN62  TN63  TN64  TN65  TN66  TN67  TN68  TN69  TN70  TN71
# 0   114   111   185   144   134   158   105   143   116   161
# 1    27    52    63    92    31    52    44    53    33    40
# 2   710  1360  1277  1291   554  1225   956  1166   571   936
# 3     3     1     2     5     5     3    11     5    13     2
# 4   271   273   423   226   242   216   365   414   313   316
#
# [5 rows x 135 columns]

# %% [markdown]
# #### Exploring the Zebra Finch RNA-Seq Data
#
# In this RNA-Seq dataset, we delve into the complex world of the Zebra Finch by examining gene expression in three distinct areas of the brain: the hypothalamus, the bed nucleus of the stria terminalis, and the nucleus taeniae. Each of these regions plays a unique role in bird behavior and physiology.
#
# - **The Hypothalamus** (HY samples): This region is crucial for controlling hormones and basic survival functions like feeding, fighting, fleeing, and reproduction.
# - **The Bed Nucleus of the Stria Terminalis** (NST samples): This area is involved in the bird's stress response and emotional behavior.
# - **The Nucleus Taeniae** (TN samples): An area of the brain unique to birds, thought to be involved in social behaviors and possibly song learning.
#
# These regions were likely chosen for their significant roles in behaviors that are crucial for survival and species-specific activities. By analyzing gene expression in these areas, researchers can gain insights into how these regions contribute to the unique behaviors of the Zebra Finch.
#
# **Dataset Breakdown**
#
# Each row in the dataset represents a different gene, identified by a geneID like `ENSTGUG00000008284`. The columns, labeled with codes like `HY3`, `HY4`, `NST3`, etc., correspond to samples from these three brain regions. The numbers are read counts, indicating how often each gene's RNA was detected in the sample. High numbers suggest a gene is very active in that sample.
#
# These numbers are crucial. They tell us how active each gene was in each sample. The higher the number, the more active the gene. By comparing these numbers across different samples, we can get insights into how gene activity varies in different situations or conditions.
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer these questions!</strong>
# </blockquote>
#
# **Questions**
#
# 1. Why do you think the read counts vary between different genes in the same sample? What biological factors might contribute to this variation?
# 2. Can you think of any reasons why the read counts for the same gene might vary between different samples? Consider the experimental design and the nature of biological systems.
# 3. How would you interpret a situation where a gene has a high read count in one sample and a low read count in another? What might this tell us about the gene's role in the Zebra Finch's response to its social environment and the LPS challenge?
#
#
# **Before proceeding, it's essential to ensure you have a foundational understanding of RNA-Seq, the objectives and design of the experiment we're examining, and the significance of each cell in the dataset. Grasping these concepts is crucial for successfully navigating the tasks ahead.**
#
# ---

# %% [markdown]
# Q1) Why do you think the read counts vary between different genes in the same sample? What biological factors might contribute to this variation?
# 1. Gene Expression Levels: Some genes are naturally expressed at higher levels than others. This can be due to differences in the promoter strength, the stability of the mRNA, or the efficiency of translation. Genes with higher expression levels will have more RNA molecules available for sequencing, resulting in higher read counts.
# 2. Transcription Efficiency: The efficiency of transcription can vary among genes. Some genes may be transcribed more efficiently than others, leading to a higher proportion of successfully translated mRNA molecules.
# 3. mRNA Stability: The stability of mRNA molecules can differ between genes. Some mRNAs are more stable and resistant to degradation, while others are more prone to degradation. Stable mRNAs will have a longer lifespan in the cell and thus be more likely to be captured by the sequencing process.
# 4. Post-Transcriptional Modifications: Post-transcriptional modifications, such as editing, methylation, or splicing, can affect the abundance of mRNA molecules. These modifications can increase or decrease the stability or translational efficiency of certain mRNAs, leading to variations in read counts.
# 5. Cellular Conditions: The state of the cell can influence gene expression. Factors such as nutrient availability, stress, temperature, and the presence of other cells or molecules can alter the expression levels of genes.
# 6. Sample Complexity: The complexity of the sample, including the presence of multiple cell types or stages of development, can also contribute to variability in read counts.

# %% [markdown]
# Q2)Can you think of any reasons why the read counts for the same gene might vary between different samples? Consider the experimental design and the nature of biological systems.
# 1. Experimental Conditions: The conditions under which the samples were taken can significantly impact gene expression. This includes environmental factors such as temperature, pH, and nutrient availability, as well as physiological conditions like metabolic rate, stress levels, and age.
# 2. Biological State: The biological state of the organism at the time of sampling can affect gene expression. For example, a gene might be expressed differently in resting versus active states, or in healthy versus diseased conditions.
# 3. Developmental Stage: If the samples come from different developmental stages of the organism, gene expression patterns can vary. For instance, a gene might be expressed at a higher level in adults compared to juveniles or vice versa.
# 4.Individual Variation: There can be individual variation in gene expression, even within the same species. This is known as genetic variation and can lead to differences in gene expression between individuals.
# 5. Cell Type: If the samples contain different cell types, the expression of certain genes may vary. For example, a gene might be expressed predominantly in neurons but not in muscle cells.
# 6. Sequencing Errors: Sequencing errors can also contribute to variations in read counts. These errors can be introduced at various stages of the sequencing process and can lead to false positives or negatives.
# 7. RNA Degradation: RNA molecules can degrade over time, especially if the samples are not immediately frozen after collection. This degradation can lead to a loss of RNA and subsequently lower read counts.
# 8. Extraction Efficiency: The efficiency of RNA extraction can vary between samples, which can affect the amount of RNA available for sequencing and thus the read counts.

# %% [markdown]
# Q3) How would you interpret a situation where a gene has a high read count in one sample and a low read count in another? What might this tell us about the gene's role in the Zebra Finch's response to its social environment and the LPS challenge?
#
# A situation where a gene has a high read count in one sample and a low read count in another sample indicates that the gene is differentially expressed between the two samples. This means that the gene is more active or less active in one sample compared to the other. This could reflect the gene's role in the Zebra Finch's response to its social environment and the LPS challenge, depending on which samples are being compared.
# For example, if a gene has a high read count in the hypothalamus of a bird that was exposed to a social stimulus, and a low read count in the hypothalamus of a bird that was not exposed to a social stimulus, this could suggest that the gene is involved in the neural processing of social information or the regulation of social behavior. Alternatively, if a gene has a high read count in the spleen of a bird that was injected with LPS, and a low read count in the spleen of a bird that was injected with a vehicle, this could imply that the gene is involved in the immune response to bacterial infection or the inflammation caused by LPS.
# To confirm the role of a gene in the Zebra Finch's response to its social environment and the LPS challenge, however, it is not enough to rely on the read counts alone. Other factors, such as gene length, expression level, regulation, and technical variation, can also affect the read counts and introduce bias or error. Therefore, it is important to perform further analysis, such as differential expression analysis, functional enrichment analysis, clustering and dimensionality reduction, and visualization and exploration, to validate and interpret the results. Additionally, it is useful to compare the results with previous studies that have investigated the transcriptomic response of Zebra Finch or other birds to social stimuli or LPS challenge.

# %% [markdown]
# ## Preprocessing and Normalization
#
# In this section, we begin our data analysis by focusing on preprocessing and normalization. Preprocessing involves converting the raw Ensembl gene IDs into more recognizable gene symbols, enhancing the interpretability of our data. Following this, normalization is performed to adjust for variations in sequencing depth and gene length, a crucial step to ensure accurate comparison of gene expression across different samples.

# %% [markdown]
# ### Transforming and Merging the Dataset for Analysis
#
# To facilitate our analysis, we need to restructure the gene expression data so that each row corresponds to a sample, with appropriate labels for social settings and tissue types. This transformation will enable us to apply machine learning techniques and conduct more effective analyses.
#
# The process involves two main steps:
# 1. **Transpose the Gene Expression Data**: Convert the gene expression data so that each row represents a sample and each column corresponds to a gene.
# 2. **Merge with Sample Mapping**: Combine the transposed gene expression data with the `sample_mapping.csv` to add social setting, study group, and tissue type information to each sample.
#
# This approach will create a dataset better suited for exploratory data analysis, clustering, and other statistical methods.

# %%
import pandas as pd

# Load the gene expression data
expression_data = pd.read_csv('/content/drive/MyDrive/GSE203528_readcount.xls', sep='\t')

# Transpose the dataframe so that columns become rows and vice versa
transposed_df = expression_data.set_index('geneID').T.reset_index()
transposed_df.rename(columns={'index': 'tissue_id'}, inplace=True)

# Load the sample mapping data
sample_mapping = pd.read_csv('/content/drive/MyDrive/sample_mappings.csv')

# Merge the transposed gene expression data with the sample mapping
merged_df = pd.merge(transposed_df, sample_mapping, on='tissue_id')

# Reorder columns to place metadata columns at the front
metadata_columns = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
gene_columns = [col for col in merged_df.columns if col not in metadata_columns]
transformed_df = merged_df[metadata_columns + gene_columns]

# Save the transformed and merged dataset
transformed_df.to_csv('/content/drive/MyDrive/transformed_dataset.csv', index=False)

# Display the first few rows of the transformed dataset
display(transformed_df.head())
# Out:
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284  \
# 0  GSM6175777              NF           L       HY3                 145
# 1  GSM6175779             ISO           S       HY5                 149
# 2  GSM6175780             ISO           L       HY6                 121
# 3  GSM6175781             ISO           L       HY8                 159
# 4  GSM6175782             ISO           L       HY9                 172
#
#    ENSTGUG00000003938  ENSTGUG00000011987  ENSTGUG00000017592  \
# 0                  25                 915                   5
# 1                  21                 938                   5
# 2                  29                 638                  14
# 3                  22                 900                   5
# 4                  38                 749                   4
#
#    ENSTGUG00000009442  ENSTGUG00000009764  ...  ENSTGUG00000010786  \
# 0                 226                  94  ...                 443
# ...

# %% [markdown]
# ### Converting Ensembl IDs to Gene Names (Bonus)
#
# In our dataset, genes are currently identified by Ensembl IDs. While these IDs are precise, they may not be as immediately recognizable as standard gene names. For those interested in working with more familiar gene names, there's a straightforward way to annotate these IDs.
#
# **Steps to Annotate Gene IDs:**
# 1. **Use MyGeneInfo Library**: MyGeneInfo is a powerful tool for gene annotation. It allows you to query a database with Ensembl IDs and retrieve corresponding standard gene names.
# 2. **Query for Zebra Finch Genes**: Given that our study is on Zebra Finch, it's important to use the correct NCBI taxonomy ID (59729) for this species when querying.
# 3. **Merge Results with Original Data**: After obtaining the gene names, you can merge this information back into your dataset, linking each Ensembl ID to its standard gene name.
#
# **Python Implementation**:
# If you wish to perform this annotation, you can use the Python library `mygene`. Initialize a `MyGeneInfo` object, query using your list of Ensembl IDs, and then merge the results with your dataset. This process adds a column for gene names, enhancing the readability and interpretability of your data.
#
# Remember, while this annotation adds clarity, the original Ensembl IDs are crucial for maintaining the accuracy and precision of genomic data.

# %%
# !pip install mygene

# %%
import mygene

# %%
mg = mygene.MyGeneInfo()

# %%
df_read_counts['geneID']
# Out:
# 0        ENSTGUG00000008284
# 1        ENSTGUG00000003938
# 2        ENSTGUG00000011987
# 3        ENSTGUG00000017592
# 4        ENSTGUG00000009442
#                 ...
# 15787    ENSTGUG00000005605
# 15788    ENSTGUG00000018403
# 15789    ENSTGUG00000014724
# 15790    ENSTGUG00000006479
# 15791    ENSTGUG00000017416
# Name: geneID, Length: 15792, dtype: object

# %%
ensembl_ids = ['ENSTGUG00000014724']  # Replace with your actual Ensembl IDs
results = mg.getgenes(ensembl_ids, fields='name')
# Out:
# INFO:biothings.client:querying 1-1...
# INFO:biothings.client:done.

# %%
 mg.getgene('ENSG00000123374', fields='name')
# Out:
# {'_id': '1017', '_version': 1, 'name': 'cyclin dependent kinase 2'}

# %%
def get_gene_name(ensembl_id):
    try:
        return mg.getgene(ensembl_id, fields='name')[0]['name']
    except Exception as e:
        print(f"Error retrieving gene name for {ensembl_id}: {e}")
        return None

# Apply the function to the 'ensembl_id' column and store the results in a new column 'gene_name'
df_read_counts['gene_name'] = df_read_counts['geneID'].apply(get_gene_name)
# Out:
# Error retrieving gene name for ENSTGUG00000008284: 'NoneType' object is not subscriptable
# Error retrieving gene name for ENSTGUG00000003938: 0
# Error retrieving gene name for ENSTGUG00000011987: 0
# Error retrieving gene name for ENSTGUG00000017592: 0
# Error retrieving gene name for ENSTGUG00000009442: 0
# Error retrieving gene name for ENSTGUG00000009764: 0
# Error retrieving gene name for ENSTGUG00000015152: 'NoneType' object is not subscriptable
# Error retrieving gene name for ENSTGUG00000002407: 0
# Error retrieving gene name for ENSTGUG00000016201: 'NoneType' object is not subscriptable
# Error retrieving gene name for ENSTGUG00000004296: 0
# Error retrieving gene name for ENSTGUG00000003903: 'NoneType' object is not subscriptable
# Error retrieving gene name for ENSTGUG00000013480: 'NoneType' object is not subscriptable
# Error retrieving gene name for ENSTGUG00000008626: 0
# Error retrieving gene name for ENSTGUG00000014195: 'NoneType' object is not subscriptable
# ...

# %% [markdown]
# I ran the code and stoped it! Because there seems to take a lot of time this way!!!!! ="(

# %%
results
# Out:
# [{'query': 'ENSTGUG00000014724', 'notfound': True}]

# %%
ensembl_ids = transformed_df#.columns[4:20] # REMOVE 20 IN FINAL VERSION
gene_info = mg.getgenes(ensembl_ids, fields='name')
# Out:
# INFO:biothings.client:querying 1-1000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 1001-2000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 2001-3000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 3001-4000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 4001-5000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 5001-6000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 6001-7000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 7001-8000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 8001-9000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 9001-10000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 10001-11000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 11001-12000...
# INFO:biothings.client:done.
# INFO:biothings.client:querying 12001-13000...
# INFO:biothings.client:done.
# ...

# %%
gene_info
# Out:
# [{'query': 'sample_id', 'notfound': True},
#  {'query': 'social_settting', 'notfound': True},
#  {'query': 'study_group', 'notfound': True},
#  {'query': 'tissue_id', 'notfound': True},
#  {'query': 'ENSTGUG00000008284', 'notfound': True},
#  {'query': 'ENSTGUG00000003938',
#   '_id': '100232169',
#   '_version': 1,
#   'name': 'vasorin'},
#  {'query': 'ENSTGUG00000011987',
#   '_id': '100223064',
#   '_version': 1,
#   'name': 'lysosomal protein transmembrane 4 beta'},
#  {'query': 'ENSTGUG00000017592',
#   '_id': '100886584',
#   '_version': 2,
#   'name': 'microRNA mir-125-2'},
#  {'query': 'ENSTGUG00000009442',
#   '_id': '100219829',
#   '_version': 1,
#   'name': 'proteasome 26S subunit, non-ATPase 6'},
#  {'query': 'ENSTGUG00000009764',
#   '_id': '101232999',
#   '_version': 1,
#   'name': 'CD38 molecule'},
#  {'query': 'ENSTGUG00000015152', 'notfound': True},
#  {'query': 'ENSTGUG00000002407',
#   '_id': '100225470',
#   '_version': 1,
#   'name': 'semaphorin 3D'},
# ...

# %%
import copy

# %%
df_holder = copy.deepcopy(df_read_counts)

# %%
df_holder.head
# Out:
# <bound method NDFrame.head of                    geneID   HY3   HY4   HY5   HY6   HY8   HY9  HY12  HY13  \
# 0      ENSTGUG00000008284   145   113   149   121   159   172   133   153
# 1      ENSTGUG00000003938    25    18    21    29    22    38    23    34
# 2      ENSTGUG00000011987   915   681   938   638   900   749   736   717
# 3      ENSTGUG00000017592     5     5     5    14     5     4    22    13
# 4      ENSTGUG00000009442   226   211   221   257   202   197   231   201
# ...                   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 18613  ENSTGUG00000014656     0     1     0     1     5     5     3     3
# 18614  ENSTGUG00000003563  1473  1409  1522  1320  1542  1267  1350  1176
# 18615  ENSTGUG00000002845    43    36    37    22    57    24    80   104
# 18616  ENSTGUG00000009990   276   155   145   174   219   157   213   206
# 18617  ENSTGUG00000001666   181   118   118   110   116    88   131   115
#
# ...

# %%
type(gene_info[1000])
# Out:
# dict

# %%
gene_info[1000]
# Out:
# {'query': 'ENSTGUG00000003566', '_id': 'ENSTGUG00000003566', '_version': 1}

# %%
# Create a new empty column in the DataFrame to store the names
df_holder['gene_name'] = None

# Loop through the list of dictionaries
for gene_dict in gene_info:
    # Check if the 'query' key exists in the dictionary
    if 'query' in gene_dict:
        # Find the index of the row where 'geneid' matches the 'query'
        matching_index = df_holder[df_holder['geneID'] == gene_dict['query']].index

        # If there's a match and the dictionary contains a 'name' key
        if not matching_index.empty and 'name' in gene_dict:
            # Add the name to the new column for all matching rows
            df_holder.loc[matching_index, 'gene_name'] = gene_dict['name']

# %%
df_holder.head
# Out:
# <bound method NDFrame.head of                    geneID   HY3   HY4   HY5   HY6   HY8   HY9  HY12  HY13  \
# 0      ENSTGUG00000008284   145   113   149   121   159   172   133   153
# 1      ENSTGUG00000003938    25    18    21    29    22    38    23    34
# 2      ENSTGUG00000011987   915   681   938   638   900   749   736   717
# 3      ENSTGUG00000017592     5     5     5    14     5     4    22    13
# 4      ENSTGUG00000009442   226   211   221   257   202   197   231   201
# ...                   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 18613  ENSTGUG00000014656     0     1     0     1     5     5     3     3
# 18614  ENSTGUG00000003563  1473  1409  1522  1320  1542  1267  1350  1176
# 18615  ENSTGUG00000002845    43    36    37    22    57    24    80   104
# 18616  ENSTGUG00000009990   276   155   145   174   219   157   213   206
# 18617  ENSTGUG00000001666   181   118   118   110   116    88   131   115
#
# ...

# %%
print(df_holder[['geneID', 'gene_name']])
# Out:
#                    geneID                                          gene_name
# 0      ENSTGUG00000008284                                               None
# 1      ENSTGUG00000003938                                            vasorin
# 2      ENSTGUG00000011987             lysosomal protein transmembrane 4 beta
# 3      ENSTGUG00000017592                                 microRNA mir-125-2
# 4      ENSTGUG00000009442               proteasome 26S subunit, non-ATPase 6
# ...                   ...                                                ...
# 18613  ENSTGUG00000014656                                               None
# 18614  ENSTGUG00000003563  glutamate ionotropic receptor AMPA type subunit 3
# 18615  ENSTGUG00000002845                                               None
# 18616  ENSTGUG00000009990                   URB2 ribosome biogenesis homolog
# 18617  ENSTGUG00000001666  core 1 synthase, glycoprotein-N-acetylgalactos...
#
# [18618 rows x 2 columns]

# %% [markdown]
# ### Normalization of RNA-Seq Data: Ensuring Accurate Comparisons
#
# Normalization is a crucial step in data analysis. In this context, it corrects for variations in sequencing depth and gene length across samples, enabling accurate comparisons of gene expression levels. Without normalization, differences in read counts could be mistakenly attributed to biological variation instead of technical biases.
#
# **Why Normalize?**
# - **Sequencing Depth Variability**: Different samples might have varying total numbers of reads due to differences in sequencing efficiency. Normalization adjusts for these discrepancies.
# - **Gene Length Bias**: Longer genes tend to have more reads merely due to their size. Normalization methods like TPM (Transcripts Per Million) correct for this by accounting for gene length.
#
# **Normalization Method - Counts Per Million (CPM)**:
# - We'll use the CPM method for its simplicity and effectiveness. CPM normalizes gene expression measurements by dividing the read counts of each gene by the total read counts per million in each sample. This method is suitable for datasets where the focus is on comparing expression patterns rather than quantifying absolute expression levels.
#
# **Implementing CPM in Python**:
# The following Python code demonstrates how to apply CPM normalization to our dataset. It involves calculating the total read counts for each sample, normalizing each gene's read count, and then multiplying by one million.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('/content/drive/MyDrive/transformed_dataset.csv')

# Function to calculate CPM
def calculate_cpm(df):
    total_reads = df.sum(axis=0)
    cpm = (df / total_reads) * 1e6
    return cpm

# Apply CPM normalization (excluding metadata columns)
metadata_cols = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
expression_data = df.drop(columns=metadata_cols)
normalized_df = calculate_cpm(expression_data)

# Combine the normalized data with the metadata
normalized_df = pd.concat([df[metadata_cols], normalized_df], axis=1)

# Save the normalized dataset
normalized_df.to_csv('/content/transformed_dataset2.csv', index=False)

# Display the first few rows of the normalized dataset
display(normalized_df.head())
# Out:
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284  \
# 0  GSM6175777              NF           L       HY3         7916.143473
# 1  GSM6175779             ISO           S       HY5         8134.519845
# 2  GSM6175780             ISO           L       HY6         6605.885243
# 3  GSM6175781             ISO           L       HY8         8680.460774
# 4  GSM6175782             ISO           L       HY9         9390.183982
#
#    ENSTGUG00000003938  ENSTGUG00000011987  ENSTGUG00000017592  \
# 0         5231.219920         8352.808004         5319.148936
# 1         4394.224733         8562.769298         5319.148936
# 2         6068.215108         5824.143723        14893.617021
# 3         4603.473530         8215.876725         5319.148936
# 4         7951.454279         6837.435186         4255.319149
#
#    ENSTGUG00000009442  ENSTGUG00000009764  ...  ENSTGUG00000010786  \
# 0         6991.276372         7795.007878  ...         9225.899161
# ...

# %% [markdown]
# ### Exploratory Data Analysis: Uncovering Patterns in Gene Expression
#
# Exploratory Data Analysis (EDA) is an essential phase in RNA-Seq data analysis, aimed at visualizing and summarizing data to uncover underlying patterns and trends. For this demonstration, we'll focus on visualizing gene expression differences across study groups ('L' for LPS treatment and 'S' for control) and social settings.
#
# **Key Focus Areas for Our Visualization:**
# 1. **Comparing 'L' and 'S' Study Groups**: This helps us understand the impact of LPS treatment versus control on gene expression.
# 2. **Role of Social Settings**: We'll also explore how different social interactions might influence gene expression patterns.
#
# This demonstration is a starting point for EDA. You are encouraged to explore various aspects of the data through diverse visualizations and analyses.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the normalized dataset
df = pd.read_csv('/content/transformed_dataset2.csv')
#print(df.head)
# Select a gene for visualization (example: 'ENSTGUG00000004743', which is Brain-Derived Neurotrophic Factor gene)
selected_gene = 'ENSTGUG00000004743'#'ENSTGUG00000008284'

# Map the social setting abbreviations to full descriptions
social_setting_map = {
    'ISO': 'Isolated',
    'KFC': 'Known Female Continuous',
    'KF': 'Known Female Reunited',
    'NF': 'Novel Female'
}
df['social_settting'] = df['social_settting'].map(social_setting_map)


# Create a boxplot comparing gene expression across study groups and social settings
plt.figure(figsize=(12, 6))
sns.boxplot(x='social_settting', y=selected_gene, hue='study_group', data=df, palette="Set2")
plt.title('Gene Expression of ' + selected_gene + ' Across Study Groups and Social Settings')
plt.ylabel('Expression Level (CPM)')
plt.xlabel('Social Setting')
plt.legend(title='Study Group')
plt.show()

# %%
gene_row = df[df.columns[df.columns.str.contains(selected_gene)]]

# Print the row related to the selected_gene
print("Row related to", selected_gene)
print(gene_row)
# Out:
# Row related to ENSTGUG00000004743
#      ENSTGUG00000004743
# 0           4851.120776
# 1           4098.360656
# 2           3512.880562
# 3           3512.880562
# 4           2843.760455
# ..                  ...
# 126         9200.401472
# 127        12964.202074
# 128        14218.802275
# 129        15975.242556
# 130        10287.721646
#
# [131 rows x 1 columns]

# %%
df.columns.str.contains(selected_gene)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
# Filter data for the selected gene
#gene_data = rna_data[['SocialCondition', 'BrainRegion', selected_gene]]

# Boxplot to visualize the distribution of gene expression across social conditions
plt.figure(figsize=(12, 6))
sns.boxplot(x='social_settting', y=selected_gene, data=df, hue='study_group')
plt.title(f'Distribution of {selected_gene} Across Social Conditions')
plt.xlabel('Social Condition')
plt.ylabel(f'{selected_gene} Expression')
plt.show()

# %%
# Create a new column 'Region' based on the starting characters of 'tissue_id'
df['Region'] = df['tissue_id'].apply(lambda x: x[:2])

# Boxplot to visualize the distribution of gene expression across brain regions, separated by study_group
plt.figure(figsize=(12, 6))
ax = sns.boxplot(x='Region', y=selected_gene, hue='study_group', data=df, palette="Set2")
plt.title(f'Distribution of {selected_gene} Across Brain Regions by Study Group')
plt.xlabel('Brain Region')
plt.ylabel(f'{selected_gene} Expression')

# Draw lines to separate the sections
line_positions = [0.5, 1.5, 2.5]
for line_pos in line_positions:
    ax.axvline(x=line_pos, color='black', linestyle='--', linewidth=1)

# Annotate the count in each region
region_counts = df['Region'].value_counts().sort_index()
for i, count in enumerate(region_counts):
    plt.text(line_positions[i], ax.get_ylim()[1] + 0.02, f'Count: {count}', ha='center')

plt.legend(title='Study Group', bbox_to_anchor=(1, 1))
plt.show()

# %%
plt.figure(figsize=(16, 8))
ax = sns.boxplot(x='Region', y=selected_gene, hue='study_group', data=df, palette="Set2", dodge=True)
ax = sns.swarmplot(x='Region', y=selected_gene, hue='social_settting', data=df, palette="Set1", size=4, dodge=True)
plt.title(f'Distribution of {selected_gene} Across Brain Regions by Study Group and Social Setting')
plt.xlabel('Brain Region')
plt.ylabel(f'{selected_gene} Expression')

# Draw lines to separate the sections
line_positions = [0.5, 1.5, 2.5]
for line_pos in line_positions:
    ax.axvline(x=line_pos, color='black', linestyle='--', linewidth=1)

# Annotate the count in each region
region_counts = df['Region'].value_counts().sort_index()
for i, count in enumerate(region_counts):
    plt.text(line_positions[i], ax.get_ylim()[1] + 0.02, f'Count: {count}', ha='center')

plt.legend(title='Study Group', bbox_to_anchor=(1, 1))
plt.show()

# %%
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=df, x='sample_id', y=selected_gene, hue='study_group', palette="Set2", alpha=0.6)
    plt.title('Scatter Plot of ' + selected_gene + ' Expression Across Samples')
    plt.xlabel('Sample ID')
    plt.ylabel('Expression Level (CPM)')
    plt.legend(title='Study Group')
    plt.show()

# %%
selected_columns = ['social_settting', 'Region', 'study_group', selected_gene]
df_selected = df[selected_columns]

# %%
cross_tab_data = pd.crosstab(df_selected['social_settting'], df_selected['Region'])

# Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(cross_tab_data, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
plt.title('Density of Discrete Data Based on Social Setting and Brain Region')
plt.xlabel('Brain Region')
plt.ylabel('Social Setting')
plt.show()

# %%
study_groups = df['study_group'].unique()

for study_group in study_groups:
    subset_df = df[df['study_group'] == study_group]
    cross_tab_data = pd.crosstab(subset_df['social_settting'], subset_df['Region'])

    # Heatmap for each study group
    plt.figure(figsize=(12, 8))
    sns.heatmap(cross_tab_data, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
    plt.title(f'Density of Discrete Data - Study Group: {study_group}')
    plt.xlabel('Brain Region')
    plt.ylabel('Social Setting')
    plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='social_settting', y=selected_gene, data=df, inner='quartile')
plt.title(f'Distribution of {selected_gene} Across Social Conditions')
plt.xlabel('Social Condition')
plt.ylabel(f'{selected_gene} Expression')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='study_group', y=selected_gene, hue='social_settting', data=df)
plt.title(f'Relationship between {selected_gene} and Another Variable')
plt.xlabel('Another Variable')
plt.ylabel(f'{selected_gene} Expression')
plt.legend(title='Social Condition')
plt.show()

# %% [markdown]
# **Write down your interpretation of the result of this simple barplot, that displays expression level of `BDNF` gene. First, briefly describe `BDNF` and it's function. Then, write your interpretation about any notable observation you see from the plot**
#
# **_Your Answer_**:
#
# <blockquote style="font-family:Arial; color:red; font-size:16px; border-left:0px solid red; padding: 10px;">
#     <strong>Don't forget to answer this question!</strong>
# </blockquote>

# %% [markdown]
# The BDNF gene encodes the Brain-Derived Neurotrophic Factor (BDNF), a protein found in the brain and spinal cord. BDNF plays a crucial role in the survival, growth, and differentiation of neurons, as well as in the maintenance of these cells. It is particularly active at synapses, which are the junctions where nerve cell communication occurs, and it helps regulate.
# BDNF is a member of the neurotrophin family of growth factors, which are related to the canonical nerve growth factor (NGF). BDNF binds to its receptor NTRK2 and activates signaling cascades that regulate neuronal development, plasticity, and survival. BDNF expression is reduced in several neurodegenerative diseases, such as Alzheimer, Parkinson, and Huntington disease. BDNF may also be involved in the regulation of stress response and mood disorders.

# %% [markdown]
# the first obvious thing is that the data is kind of balanced within different classes of study groups and social settings. the means are nearly closed. By observing the hit map you can see that this gene is very active in the known female reunited case whereas shows in this case when the communication gets to the higher levels you can see this impact of the gene. you can see the same impact in the isolated situation for the birds showing how loneliness can affect your genes.

# %% [markdown]
# ### Diverse Visualization Techniques for Gene Expression Data
#
# A comprehensive exploration of gene expression data requires a multifaceted visualization approach. Beyond the boxplot, we will delve into additional techniques that can bring forth deeper insights from our dataset. You are tasked with implementation and interpretation of the results of at least one of the following visualization methods:
#
# - **PCA (Principal Component Analysis)**: This technique reduces the dimensionality of the data and can reveal the underlying structure by capturing the most variation across samples.
# - **t-SNE (t-Distributed Stochastic Neighbor Embedding)**: Particularly useful for visualizing high-dimensional data in a lower-dimensional space, t-SNE can help identify clusters of genes or samples.
# - **UMAP (Uniform Manifold Approximation and Projection)**: Similar to t-SNE, UMAP is useful for visualization and can be faster and more scalable.
#
# In addition to these, consider the following methods to further dissect the dataset:
#
# - **Histograms and Density Plots**: Useful for showing the distribution of gene expression levels within individual samples or conditions.
# - **Boxplots and Violin Plots**: These can summarize the distributions and highlight potential outliers in gene expression levels across samples.
# - **Scatter Plots**: When exploring the relationship between different conditions, scatter plots can be particularly revealing.
# - **Volcano Plots**: Ideal for showcasing differential expression results, highlighting genes with significant fold changes and statistical significance.
#
# Each method will contribute to a holistic view of the dataset, enabling you to uncover patterns and anomalies that may not be apparent through a single visualization strategy.

# %% [markdown]
# #### **Your Turn to Explore**
#
# - **Experiment with Different Genes**: Change the `selected_gene` variable to analyze other genes of interest.
# - **Diverse Visualizations**: Consider using heatmaps, violin plots, or scatter plots for different perspectives.
# - **Incorporate Statistical Analyses**: Complement visual insights with statistical tests to discern if the differences you observe are significant.
#
# Remember, the goal is to thoroughly understand the dataset, paving the way for more in-depth analyses like differential gene expression or clustering.

# %%
selected_gene = 'ENSTGUG00000008284'

# %%
# Filter data for the selected gene
#gene_data = rna_data[['SocialCondition', 'BrainRegion', selected_gene]]

# Boxplot to visualize the distribution of gene expression across social conditions
plt.figure(figsize=(12, 6))
sns.boxplot(x='social_settting', y=selected_gene, data=df, hue='study_group')
plt.title(f'Distribution of {selected_gene} Across Social Conditions')
plt.xlabel('Social Condition')
plt.ylabel(f'{selected_gene} Expression')
plt.show()

# %%
plt.figure(figsize=(16, 8))
ax = sns.boxplot(x='Region', y=selected_gene, hue='study_group', data=df, palette="Set2", dodge=True)
ax = sns.swarmplot(x='Region', y=selected_gene, hue='social_settting', data=df, palette="Set1", size=4, dodge=True)
plt.title(f'Distribution of {selected_gene} Across Brain Regions by Study Group and Social Setting')
plt.xlabel('Brain Region')
plt.ylabel(f'{selected_gene} Expression')

# Draw lines to separate the sections
line_positions = [0.5, 1.5, 2.5]
for line_pos in line_positions:
    ax.axvline(x=line_pos, color='black', linestyle='--', linewidth=1)

# Annotate the count in each region
region_counts = df['Region'].value_counts().sort_index()
for i, count in enumerate(region_counts):
    plt.text(line_positions[i], ax.get_ylim()[1] + 0.02, f'Count: {count}', ha='center')

plt.legend(title='Study Group', bbox_to_anchor=(1, 1))
plt.show()

# %%
    plt.figure(figsize=(12, 6))
    sns.scatterplot(data=df, x='sample_id', y=selected_gene, hue='study_group', palette="Set2", alpha=0.6)
    plt.title('Scatter Plot of ' + selected_gene + ' Expression Across Samples')
    plt.xlabel('Sample ID')
    plt.ylabel('Expression Level (CPM)')
    plt.legend(title='Study Group')
    plt.show()

# %%
selected_columns = ['social_settting', 'Region', 'study_group', selected_gene]
df_selected = df[selected_columns]

# %%
cross_tab_data = pd.crosstab(df_selected['social_settting'], df_selected['Region'])

# Heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(cross_tab_data, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
plt.title('Density of Discrete Data Based on Social Setting and Brain Region')
plt.xlabel('Brain Region')
plt.ylabel('Social Setting')
plt.show()

# %%
study_groups = df['study_group'].unique()

for study_group in study_groups:
    subset_df = df[df['study_group'] == study_group]
    cross_tab_data = pd.crosstab(subset_df['social_settting'], subset_df['Region'])

    # Heatmap for each study group
    plt.figure(figsize=(12, 8))
    sns.heatmap(cross_tab_data, annot=True, fmt="d", cmap="YlGnBu", cbar=True)
    plt.title(f'Density of Discrete Data - Study Group: {study_group}')
    plt.xlabel('Brain Region')
    plt.ylabel('Social Setting')
    plt.show()

# %%
from scipy import stats

# %%
import pandas as pd
from scipy import stats

# Assuming df is your DataFrame and it has been loaded correctly
# Select two random gene expression columns
column1 = 'ENSTGUG00000004743'
column2 = 'ENSTGUG00000008284'

# Filter the DataFrame to include only samples from the same study group
same_group_samples = df[df['study_group'] == 'L']

# Extract the paired samples
paired_samples = same_group_samples[[column1, column2]]

# Perform the paired t-test
t_statistic, p_value = stats.ttest_rel(paired_samples[column1], paired_samples[column2])
print(f"Paired t-test result:\nT-statistic: {t_statistic}\nP-value: {p_value}")
# Out:
# Paired t-test result:
# T-statistic: -1.3045541823832913
# P-value: 0.19671649320018117

# %%
# Independent t-test
group1_samples = df[df['study_group'] == 'L'][column1].values
group2_samples = df[df['study_group'] == 'S'][column1].values
t_statistic, p_value = stats.ttest_ind(group1_samples, group2_samples)
print(f"Independent t-test result:\nT-statistic: {t_statistic}\nP-value: {p_value}")
# Out:
# Independent t-test result:
# T-statistic: -1.4063031003749782
# P-value: 0.1620384584409782

# %% [markdown]
# in both statistical tests you can see that the test is passed andyou can see that 2 groups of study hold a difference both in one column and 2 column case!!!

# %% [markdown]
# the first obvious thing is that the data is kind of balanced within different classes of study groups and social settings. the means are nearly closed. By observing the hit map you can see that this gene is very active in the known female reunited case whereas shows in this case when the communication gets to the higher levels you can see this impact of the gene. you can see the same impact in the isolated situation for the birds showing how loneliness can affect your genes. The scatter plots show that different samples of the same gene are not very apart from each other, despite the difference in labels.

# %%
### TODO ###

# %% [markdown]
# ### Reflecting on Visualizations to Extract Key Insights
#
# As we have navigated through different visualization strategies, it's time to consolidate the knowledge you've gained. Reflect on the insights each visualization has provided:
#
# - **What trends have you observed in the distribution of gene expression levels?**
# - **How do the expression levels compare when you look across different conditions or samples?**
# - **From the heatmap, were you able to detect any consistent patterns of expression, such as upregulation or downregulation of certain genes?**
# - **Did any outliers or unusual expression patterns emerge? What might these suggest about certain genes or the overall data quality?**
#
# Write down your observations and hypotheses. Discuss and note down your interpretations as they will be valuable for the upcoming stages of differential gene expression analysis.
#
# **_Your Answer_**:

# %% [markdown]
# we can say that genes are sensitive to the social setting related to the samples and the could be found in different samples in different settings and known female reunited has the mos impact of genes because in every region we have a lot of that and also in the NS regions we have most rate of repeated genes shows that this area is so sensitive compared to the others.

# %% [markdown]
# ---

# %% [markdown]
# ### Differential Gene Expression Analysis
#
# After exploring the general patterns in our dataset, the next step is Differential Gene Expression (DGE) analysis. This process will help us identify genes whose expression levels significantly differ across treatments or social settings.
#
# #### Addressing High Dimensionality in RNA-Seq Data for Differential Gene Expression Analysis
#
# In RNA-Seq data, high dimensionality (a large number of genes) presents several analytical challenges. This complexity can obscure meaningful biological insights and impact the statistical power of our analyses.
#
# **Challenges of High Dimensionality**:
# 1. **Statistical Power Loss**: With too many variables (genes), the risk of finding false positives increases, known as the 'multiple testing problem'.
# 2. **Overfitting Risk**: High-dimensional data can lead to models that are too complex, capturing noise rather than true underlying patterns.
# 3. **Computational Intensity**: Analyzing thousands of genes simultaneously demands significant computational resources and time.
# 4. **Interpretation Difficulty**: It becomes challenging to interpret results and extract biologically meaningful conclusions from a vast pool of data.
#
# **Addressing These Challenges**:
# 1. **Dimensionality Reduction**: Techniques like PCA (Principal Component Analysis) and t-SNE (t-Distributed Stochastic Neighbor Embedding) help in reducing the number of dimensions, making the data more manageable and revealing hidden structures.
# 2. **RNA-Seq Specific Tools for DGE Analysis**: Tools like DESeq2 and edgeR (available in Python through rpy2 or similar interfaces) are designed to handle high-dimensional data. They offer:
#    - **Normalization and Variance Stabilization**: Tailored for RNA-Seq data, ensuring fair comparisons across samples.
#    - **FDR Control**: Implement procedures to adjust for multiple comparisons, reducing false positives.
#    - **Biological Variance Modeling**: Consider the biological variability, enhancing the reliability of results.
#
# **Python Implementation**:
# - In python environments, the use of R-based tools like DESeq2 or edgeR is possible through interfaces such as `rpy2`. This approach allows you to leverage the strengths of these tools while working within a Python framework. However, as stated multiple times in this project, you have freedom to choose alternative method for any task, as long as it makes sense.

# %%
import numpy as np

class PCA:
    def __init__(self, n_components):
        self.n_components = n_components
        self.components_ = None

    def fit(self, X):
        """Fit the model with X.

        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where `n_samples` is the number of samples
            and `n_features` is the number of features.

        Returns
        -------
        self : object
            Returns the instance itself.
        """
        self.components_ = None

        # Center the data
        X_centered = X - np.mean(X, axis=0)

        # Compute the covariance matrix
        covariance = np.cov(X_centered, rowvar=False)

        # Compute the eigenvalues and eigenvectors of the covariance matrix
        eigenvalues, eigenvectors = np.linalg.eig(covariance)

        # Sort the eigenvalues and eigenvectors in descending order
        sorted_indices = np.argsort(eigenvalues)[::-1]
        eigenvalues = eigenvalues[sorted_indices]
        eigenvectors = eigenvectors[:, sorted_indices]

        # Select the top n_components eigenvectors as the principal components
        self.components_ = eigenvectors[:, :self.n_components]

        return self

    def transform(self, X):
        """Fit the model with X and apply the dimensionality reduction on X.

        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where `n_samples` is the number of samples
            and `n_features` is the number of features.

        Returns
        -------
        X_new : ndarray of shape (n_samples, n_components)
            Transformed values.
        """
        assert self.components_ is not None

        # Center the data
        X_centered = X - np.mean(X, axis=0)

        # Project the centered data onto the principal components
        X_new = np.dot(X_centered, self.components_)

        return X_new

# %%
df
# Out:
#       sample_id          social_settting study_group tissue_id  \
# 0    GSM6175777             Novel Female           L       HY3
# 1    GSM6175779                 Isolated           S       HY5
# 2    GSM6175780                 Isolated           L       HY6
# 3    GSM6175781                 Isolated           L       HY8
# 4    GSM6175782                 Isolated           L       HY9
# ..          ...                      ...         ...       ...
# 126  GSM6175906  Known Female Continuous           L      TN67
# 127  GSM6175907  Known Female Continuous           S      TN68
# 128  GSM6175908  Known Female Continuous           L      TN69
# 129  GSM6175909  Known Female Continuous           S      TN70
# 130  GSM6175910  Known Female Continuous           L      TN71
#
#      ENSTGUG00000008284  ENSTGUG00000003938  ENSTGUG00000011987  \
# 0           7916.143473         5231.219920         8352.808004
# 1           8134.519845         4394.224733         8562.769298
# ...

# %%
### TODO ###
# Placeholder for PCA Analysis.

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer  # for imputing missing values



# Note: Before applying PCA, it's important to standardize the data
# Example: Standardize the gene expression data (excluding metadata columns)

# Load your expression data here
# expression_data = ...
expression_data = df.drop(['sample_id', 'social_settting', 'study_group', 'tissue_id', 'Region'], axis=1)

# Standardize the data
scaler = StandardScaler()
expression_scaled = scaler.fit_transform(expression_data)


# Impute missing values (replace NaN values with the mean of each column)
imputer = SimpleImputer(strategy='mean')
expression_data_imputed = imputer.fit_transform(expression_scaled)

# Remove rows containing NaN values
expression_data_cleaned = expression_data_imputed[~np.isnan(expression_data_imputed).any(axis=1)]


# Apply PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(expression_data_cleaned)

# Plot the PCA results
plt.figure(figsize=(10, 8))
plt.scatter(principal_components[:, 0], principal_components[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data')
plt.show()

# Tip: Explore the variance ratio to decide on the number of components
# Tip: Use annotations or different colors to highlight groups based on treatment or social settings
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1047: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1052: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1072: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
# Extract social setting column from the cleaned data
social_settings = df['social_settting'].loc[~np.isnan(expression_data_imputed).any(axis=1)].values

# Apply PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(expression_data_cleaned)
# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
print(f"Explained Variance Ratio: PC1 = {explained_variance_ratio[0]:.2f}, PC2 = {explained_variance_ratio[1]:.2f}")

# Plot the PCA results with different colors for each social setting
plt.figure(figsize=(10, 8))

# Define colors for each social setting
colors = {'Isolated': 'red', 'Known Female Continuous': 'green', 'Known Female Reunited': 'blue', 'Novel Female': 'purple'}

# Scatter plot with different colors for each social setting
for social_setting in np.unique(social_settings):
    indices = social_settings == social_setting
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1], label=social_setting, color=colors[social_setting])

# Add legend and labels
plt.legend()
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data by Social Setting')
plt.show()
# Out:
# Explained Variance Ratio: PC1 = 0.21, PC2 = 0.08

# %%
pca = PCA(n_components=3)
principal_components = pca.fit_transform(expression_data_cleaned)
# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
for i in range(len(explained_variance_ratio)):
  print(f"Explained Variance Ratio: PC{i+1} = {explained_variance_ratio[i]:.2f}")

#print(f"Explained Variance Ratio: PC1 = {explained_variance_ratio[0]:.2f}, PC2 = {explained_variance_ratio[1]:.2f}")

# Plot the PCA results with different colors for each social setting
plt.figure(figsize=(10, 8))

# Define colors for each social setting
colors = {'Isolated': 'red', 'Known Female Continuous': 'green', 'Known Female Reunited': 'blue', 'Novel Female': 'purple'}

# Scatter plot with different colors for each social setting
for social_setting in np.unique(social_settings):
    indices = social_settings == social_setting
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1], label=social_setting, color=colors[social_setting])

# Add legend and labels
plt.legend()
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data by Social Setting')
plt.show()
# Out:
# Explained Variance Ratio: PC1 = 0.21
# Explained Variance Ratio: PC2 = 0.08
# Explained Variance Ratio: PC3 = 0.04

# %%
pca = PCA(n_components=5)
principal_components = pca.fit_transform(expression_data_cleaned)
# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
#print(f"Explained Variance Ratio: PC1 = {explained_variance_ratio[0]:.2f}, PC2 = {explained_variance_ratio[1]:.2f}")
for i in range(len(explained_variance_ratio)):
  print(f"Explained Variance Ratio: PC{i+1} = {explained_variance_ratio[i]:.2f}")
# Plot the PCA results with different colors for each social setting
plt.figure(figsize=(10, 8))

# Define colors for each social setting
colors = {'Isolated': 'red', 'Known Female Continuous': 'green', 'Known Female Reunited': 'blue', 'Novel Female': 'purple'}

# Scatter plot with different colors for each social setting
for social_setting in np.unique(social_settings):
    indices = social_settings == social_setting
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1], label=social_setting, color=colors[social_setting])

# Add legend and labels
plt.legend()
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data by Social Setting')
plt.show()
# Out:
# Explained Variance Ratio: PC1 = 0.21
# Explained Variance Ratio: PC2 = 0.08
# Explained Variance Ratio: PC3 = 0.04
# Explained Variance Ratio: PC4 = 0.03
# Explained Variance Ratio: PC5 = 0.03

# %%
pca = PCA(n_components=10)
principal_components = pca.fit_transform(expression_data_cleaned)
# Explained variance ratio
explained_variance_ratio = pca.explained_variance_ratio_
#print(f"Explained Variance Ratio: PC1 = {explained_variance_ratio[0]:.2f}, PC2 = {explained_variance_ratio[1]:.2f}")
for i in range(len(explained_variance_ratio)):
  print(f"Explained Variance Ratio: PC{i+1} = {explained_variance_ratio[i]:.2f}")
# Plot the PCA results with different colors for each social setting
plt.figure(figsize=(10, 8))

# Define colors for each social setting
colors = {'Isolated': 'red', 'Known Female Continuous': 'green', 'Known Female Reunited': 'blue', 'Novel Female': 'purple'}

# Scatter plot with different colors for each social setting
for social_setting in np.unique(social_settings):
    indices = social_settings == social_setting
    plt.scatter(principal_components[indices, 0], principal_components[indices, 1], label=social_setting, color=colors[social_setting])

# Add legend and labels
plt.legend()
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA of Gene Expression Data by Social Setting')
plt.show()
# Out:
# Explained Variance Ratio: PC1 = 0.21
# Explained Variance Ratio: PC2 = 0.08
# Explained Variance Ratio: PC3 = 0.04
# Explained Variance Ratio: PC4 = 0.03
# Explained Variance Ratio: PC5 = 0.03
# Explained Variance Ratio: PC6 = 0.03
# Explained Variance Ratio: PC7 = 0.02
# Explained Variance Ratio: PC8 = 0.02
# Explained Variance Ratio: PC9 = 0.02
# Explained Variance Ratio: PC10 = 0.01

# %%
### TODO ###
# Placeholder for using a common RNA-Seq analysis tool from Python

import subprocess

# Example: Using DESeq2 via R for Differential Gene Expression Analysis
# DESeq2 is a popular tool for RNA-Seq data, particularly useful for identifying differentially expressed genes

# Define the paths and necessary arguments
r_script_path = 'path/to/deseq2_analysis.R'
input_file_path = 'path/to/normalized_dataset.csv'  # CSV file path
output_file_path = 'path/to/deseq2_output.csv'      # Path to save the DESeq2 output

# Construct the command to run the R script using subprocess
command = ['Rscript', r_script_path, input_file_path, output_file_path]

# Run the command
subprocess.run(command)

# Tips and Hints:
# - Ensure that R and DESeq2 are installed in your environment.
# - The R script should be written to take input and output file paths as arguments.
# - The script should handle the reading of the CSV file, applying DESeq2, and writing the results back to a CSV.
# - In the R script, consider using additional metadata columns (like 'study_group', 'social_settting') as part of the DESeq2 design formula to account for these factors in the analysis.
# - You can capture the output and errors from the subprocess to check if the script ran successfully.
# - For Python users not familiar with R, consider using Python alternatives or interfaces such as rpy2 to work with DESeq2.

# %% [markdown]
# ### Identifying Differentially Expressed Genes (DEGs)
#
# The core of our RNA-Seq analysis lies in identifying Differentially Expressed Genes (DEGs) between different conditions, such as LPS treatment vs control, and across social settings. Identifying DEGs helps in pinpointing specific genes that are responsive to our experimental treatments.
#
# **Freedom in Methodology**:
# - You are free to choose your preferred method or tool for DEG analysis. Whether it's DESeq2, edgeR, or any other method, the key is to reliably identify genes that show statistically significant differences in expression.
#
# ### Interpreting the Findings
#
# After identifying DEGs, the next crucial step is interpreting these findings. This involves understanding the biological functions and pathways these genes are involved in.
#
# **Functional Annotation and Pathway Analysis**:
# - Utilize databases like Gene Ontology (GO), Kyoto Encyclopedia of Genes and Genomes (KEGG), or DAVID for functional annotation.
# - Interpret the roles of these genes in biological processes, cellular components, and molecular functions.
#
# ### Visualization for Insightful Understanding
#
# A critical aspect of this phase is visualization. Effective visualizations can provide profound insights into the data and help in communicating your findings.
#
# **Visualizations Can Include**:
# - Heatmaps of DEGs.
# - Volcano plots showing the significance vs. fold-change.
# - Pathway diagrams to illustrate the affected biological pathways.
#
# ### Emphasis on Interpretation and Informative Visualization
#
# Remember, the ultimate goal is to not only identify DEGs but to also understand their biological significance and visually represent this information in an insightful and informative manner. Your interpretations and visualizations are crucial for translating raw data into meaningful biological insights.

# %%
### TODO ###
# Placeholder for DEG Analysis, Interpretation, and Visualization

# Step 1: DEG Analysis
# Use your chosen tool/method to identify DEGs
# Example: results = DESeq2_DEG_analysis(input_file)

# Step 2: Functional Annotation
# Utilize online databases or tools for gene annotation
# Example: annotated_genes = annotate_genes(results['gene_id'])

# Step 3: Pathway Analysis
# Map the DEGs to biological pathways
# Example: pathways = map_to_pathways(annotated_genes)

# Step 4: Visualization
# Create insightful visualizations of the DEGs
# Example: create_heatmap(results)
# Example: create_volcano_plot(results)
# Example: plot_pathways(pathways)

# Remember to interpret your findings in the context of the biological questions and hypotheses you are exploring.
# Consider the biological significance of the DEGs and their roles in the context of your study.

# %%
# !pip install pydeseq2

# %%
# %pip install pydeseq2

# %%
from pydeseq2.dds import DeseqDataSet
from pydeseq2.ds import DeseqStats

# %%
import pandas as pd

# Load the gene expression data
expression_data = pd.read_csv('/content/drive/MyDrive/GSE203528_readcount.xls', sep='\t')

# Transpose the dataframe so that columns become rows and vice versa
transposed_df = expression_data.set_index('geneID').T.reset_index()
transposed_df.rename(columns={'index': 'tissue_id'}, inplace=True)

# Load the sample mapping data
sample_mapping = pd.read_csv('/content/drive/MyDrive/sample_mappings.csv')

# Merge the transposed gene expression data with the sample mapping
merged_df = pd.merge(transposed_df, sample_mapping, on='tissue_id')

# Reorder columns to place metadata columns at the front
metadata_columns = ['sample_id', 'social_settting', 'study_group', 'tissue_id']
gene_columns = [col for col in merged_df.columns if col not in metadata_columns]
transformed_df = merged_df[metadata_columns + gene_columns]

# Save the transformed and merged dataset
#transformed_df.to_csv('/content/drive/MyDrive/transformed_dataset.csv', index=False)
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='mean')
#transformed_df = imputer.fit_transform(transformed_df)

# Remove rows containing NaN values
#transformed_df = transformed_df[~np.isnan(transformed_df).any(axis=1)]

transformed_df = transformed_df.dropna()
transformed_df = transformed_df[transformed_df.sum(axis = 1) > 0]
# Display the first few rows of the transformed dataset
display(transformed_df.head())
# Out:
#     sample_id social_settting study_group tissue_id  ENSTGUG00000008284  \
# 0  GSM6175777              NF           L       HY3               145.0
# 1  GSM6175779             ISO           S       HY5               149.0
# 2  GSM6175780             ISO           L       HY6               121.0
# 3  GSM6175781             ISO           L       HY8               159.0
# 4  GSM6175782             ISO           L       HY9               172.0
#
#    ENSTGUG00000003938  ENSTGUG00000011987  ENSTGUG00000017592  \
# 0                25.0               915.0                 5.0
# 1                21.0               938.0                 5.0
# 2                29.0               638.0                14.0
# 3                22.0               900.0                 5.0
# 4                38.0               749.0                 4.0
#
#    ENSTGUG00000009442  ENSTGUG00000009764  ...  ENSTGUG00000013189  \
# 0               226.0                94.0  ...               278.0
# ...

# %%
filtered_columns = transformed_df.drop(columns=["social_settting",	"study_group",	"tissue_id"])
filtered_columns = filtered_columns.set_index('sample_id')
filtered_columns
# Out:
#             ENSTGUG00000008284  ENSTGUG00000003938  ENSTGUG00000011987  \
# sample_id
# GSM6175777               145.0                25.0               915.0
# GSM6175779               149.0                21.0               938.0
# GSM6175780               121.0                29.0               638.0
# GSM6175781               159.0                22.0               900.0
# GSM6175782               172.0                38.0               749.0
# GSM6175783               133.0                23.0               736.0
# GSM6175784               153.0                34.0               717.0
# GSM6175785               192.0                35.0               657.0
# GSM6175786               140.0                75.0               686.0
# GSM6175787               160.0                38.0               638.0
# GSM6175788               144.0                25.0               955.0
# GSM6175789               180.0                40.0               717.0
#
# ...

# %%
selected_columns = transformed_df[["sample_id", "social_settting",	"study_group",	"tissue_id"]]
selected_columns = selected_columns.set_index('sample_id')
selected_columns
# Out:
#            social_settting study_group tissue_id
# sample_id
# GSM6175777              NF           L       HY3
# GSM6175779             ISO           S       HY5
# GSM6175780             ISO           L       HY6
# GSM6175781             ISO           L       HY8
# GSM6175782             ISO           L       HY9
# GSM6175783             ISO           S      HY12
# GSM6175784             ISO           S      HY13
# GSM6175785             ISO           L      HY14
# GSM6175786             ISO           L      HY16
# GSM6175787              NF           L      HY19
# GSM6175788              NF           S      HY20
# GSM6175789              NF           L      HY24

# %%
dds = DeseqDataSet(counts=filtered_columns,
            metadata=selected_columns,
            design_factors="study_group")
# Out:
# <ipython-input-7-76bbd9588ee0>:1: UserWarning: Same factor names in the design contain underscores ('_'). They will
#                 be converted to hyphens ('-').
#   dds = DeseqDataSet(counts=filtered_columns,

# %%
dds.deseq2()

# %%
dds

# %%
dds.design_factors

# %%
stat_res = DeseqStats(dds, contrast = ("study-group",'L','S'))

# %%
stat_res.summary()

# %%
res = stat_res.results_df

# %%
res
# Out:
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSTGUG00000008284  153.250189        0.061794  0.149819  0.412457  0.680004
# ENSTGUG00000003938   33.874202        0.497261  0.363909  1.366441  0.171801
# ENSTGUG00000011987  765.322113       -0.260081  0.116447 -2.233465  0.025518
# ENSTGUG00000017592   10.215077       -0.561700  0.514938 -1.090810  0.275357
# ENSTGUG00000009442  227.599403        0.047786  0.167182  0.285832  0.775007
# ...                        ...             ...       ...       ...       ...
# ENSTGUG00000005605    0.424525        1.742296  2.846117  0.612166  0.540428
# ENSTGUG00000018403  560.130458        0.080536  0.097607  0.825107  0.409311
# ENSTGUG00000014724    7.945951        0.434903  0.526703  0.825708  0.408970
# ENSTGUG00000006479  619.856201        0.171129  0.080062  2.137458  0.032561
# ENSTGUG00000017416  444.620825       -0.042794  0.713806 -0.059952  0.952194
#
#                         padj
# ...

# %%
# Example: create_heatmap(results)
# Example: create_volcano_plot(results)
# Example: plot_pathways(pathways)

# %%
# !pip install scanpy

# %%
import scanpy as sc

# %%
dds
# Out:
# AnnData object with n_obs × n_vars = 12 × 15792
#     obs: 'social_settting', 'study-group', 'tissue_id'
#     uns: 'trend_coeffs', '_squared_logres', 'prior_disp_var'
#     obsm: 'design_matrix', 'size_factors', 'replaceable'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks'

# %%
sc.tl.pca(dds)

# %%
sc.pl.pca(dds, color = 'study-group', size = 200)
# Out:
# /usr/local/lib/python3.10/dist-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
# !pip install gseapy

# %%
import gseapy as gp
from gseapy.plot import gseaplot

# %%
res
# Out:
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSTGUG00000008284  153.250189        0.061794  0.149819  0.412457  0.680004
# ENSTGUG00000003938   33.874202        0.497261  0.363909  1.366441  0.171801
# ENSTGUG00000011987  765.322113       -0.260081  0.116447 -2.233465  0.025518
# ENSTGUG00000017592   10.215077       -0.561700  0.514938 -1.090810  0.275357
# ENSTGUG00000009442  227.599403        0.047786  0.167182  0.285832  0.775007
# ...                        ...             ...       ...       ...       ...
# ENSTGUG00000005605    0.424525        1.742296  2.846117  0.612166  0.540428
# ENSTGUG00000018403  560.130458        0.080536  0.097607  0.825107  0.409311
# ENSTGUG00000014724    7.945951        0.434903  0.526703  0.825708  0.408970
# ENSTGUG00000006479  619.856201        0.171129  0.080062  2.137458  0.032561
# ENSTGUG00000017416  444.620825       -0.042794  0.713806 -0.059952  0.952194
#
#                         padj
# ...

# %%
sigs = res[(res.padj < 0.05) & (abs(res.log2FoldChange) > 0.5)]

# %%
sigs
# Out:
#                       baseMean  log2FoldChange     lfcSE      stat  \
# ENSTGUG00000017534  112.770886        2.586915  0.397449  6.508792
# ENSTGUG00000008084   11.795272        2.828145  0.782495  3.614268
# ENSTGUG00000012341  148.540943        1.223563  0.347100  3.525107
# ENSTGUG00000009368  142.840593        0.653734  0.176809  3.697398
# ENSTGUG00000003509  125.579995        2.899437  0.620103  4.675737
# ...                        ...             ...       ...       ...
# ENSTGUG00000005445   97.235349        1.218229  0.276752  4.401875
# ENSTGUG00000001423   80.249602        4.507655  0.552648  8.156470
# ENSTGUG00000005326   58.904297        4.942173  0.684855  7.216383
# ENSTGUG00000006609   96.915445        1.531597  0.372876  4.107524
# ENSTGUG00000005676   78.730652       -0.991027  0.254682 -3.891228
#
#                           pvalue          padj
# ENSTGUG00000017534  7.575777e-11  5.367438e-08
# ENSTGUG00000008084  3.011971e-04  3.950250e-02
# ...

# %%
sigs.rename(columns={'Column1': 'Gene ID'}, inplace=True)
# Out:
# <ipython-input-49-6fbc65b3d2bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sigs.rename(columns={'Column1': 'Gene ID'}, inplace=True)

# %%
sigs
# Out:
#                       baseMean  log2FoldChange     lfcSE      stat  \
# ENSTGUG00000017534  112.770886        2.586915  0.397449  6.508792
# ENSTGUG00000008084   11.795272        2.828145  0.782495  3.614268
# ENSTGUG00000012341  148.540943        1.223563  0.347100  3.525107
# ENSTGUG00000009368  142.840593        0.653734  0.176809  3.697398
# ENSTGUG00000003509  125.579995        2.899437  0.620103  4.675737
# ...                        ...             ...       ...       ...
# ENSTGUG00000005445   97.235349        1.218229  0.276752  4.401875
# ENSTGUG00000001423   80.249602        4.507655  0.552648  8.156470
# ENSTGUG00000005326   58.904297        4.942173  0.684855  7.216383
# ENSTGUG00000006609   96.915445        1.531597  0.372876  4.107524
# ENSTGUG00000005676   78.730652       -0.991027  0.254682 -3.891228
#
#                           pvalue          padj
# ENSTGUG00000017534  7.575777e-11  5.367438e-08
# ENSTGUG00000008084  3.011971e-04  3.950250e-02
# ...

# %%
import pandas as pd

# Assuming your DataFrame is named 'data'
first_column = sigs.iloc[:, 0]
print(sigs.index[0])
# Out:
# ENSTGUG00000017534

# %%
sigs.rename_axis('Gene_ID', inplace=True)

# %%
sigs['Gene_ID']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gene_ID'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
column_names = list(sigs.columns.values)
column_names
# Out:
# ['baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj']

# %%
dds_sigs = dds[:, sigs.index]
dds_sigs
# Out:
# View of AnnData object with n_obs × n_vars = 12 × 99
#     obs: 'social_settting', 'study-group', 'tissue_id'
#     uns: 'trend_coeffs', '_squared_logres', 'prior_disp_var', 'pca', 'study-group_colors'
#     obsm: 'design_matrix', 'size_factors', 'replaceable', 'X_pca'
#     varm: 'non_zero', '_MoM_dispersions', 'genewise_dispersions', '_genewise_converged', '_normed_means', 'fitted_dispersions', 'MAP_dispersions', '_MAP_converged', 'dispersions', '_outlier_genes', 'LFC', '_LFC_converged', 'replaced', 'PCs'
#     layers: 'normed_counts', '_mu_hat', '_mu_LFC', '_hat_diagonals', 'cooks', 'replace_cooks'

# %%
grapher = pd.DataFrame(dds_sigs.layers['replace_cooks'].T,
                       index=dds_sigs.var_names, columns=dds_sigs.obs_names)

# %%
import numpy as np
import seaborn as sns

# %%
sns.clustermap(grapher, z_score=0, cmap = 'RdYlBu_r')

# %%
holder = filtered_columns.T

# %%
holder

# %%
holder.rename_axis('Gene_ID', inplace=True)

# %%
holder['Gene_ID']

# %%
result = pd.merge(holder, sigs, left_index=True, right_index=True)#holder.join(sigs)
result
# Out:
#                     GSM6175777  GSM6175779  GSM6175780  GSM6175781  \
# Gene_ID
# ENSTGUG00000017534       263.0        27.0        71.0       298.0
# ENSTGUG00000008084        15.0         4.0        12.0        18.0
# ENSTGUG00000012341       163.0        56.0       200.0       197.0
# ENSTGUG00000009368       197.0        93.0       209.0       155.0
# ENSTGUG00000003509       219.0        32.0        76.0       497.0
# ...                        ...         ...         ...         ...
# ENSTGUG00000005445        87.0        43.0       126.0        84.0
# ENSTGUG00000001423       138.0         7.0       150.0       294.0
# ENSTGUG00000005326       161.0         2.0        10.0        98.0
# ENSTGUG00000006609       165.0        37.0        75.0       198.0
# ENSTGUG00000005676        54.0       102.0        49.0        65.0
#
#                     GSM6175782  GSM6175783  GSM6175784  GSM6175785  \
# Gene_ID
# ENSTGUG00000017534       180.0        22.0        35.0       154.0
# ...

# %%
filtered_columns
# Out:
#             ENSTGUG00000008284  ENSTGUG00000003938  ENSTGUG00000011987  \
# sample_id
# GSM6175777               145.0                25.0               915.0
# GSM6175779               149.0                21.0               938.0
# GSM6175780               121.0                29.0               638.0
# GSM6175781               159.0                22.0               900.0
# GSM6175782               172.0                38.0               749.0
# GSM6175783               133.0                23.0               736.0
# GSM6175784               153.0                34.0               717.0
# GSM6175785               192.0                35.0               657.0
# GSM6175786               140.0                75.0               686.0
# GSM6175787               160.0                38.0               638.0
# GSM6175788               144.0                25.0               955.0
# GSM6175789               180.0                40.0               717.0
#
# ...

# %%
column_names = list(holder.columns.values)
column_names
# Out:
# ['GSM6175777',
#  'GSM6175779',
#  'GSM6175780',
#  'GSM6175781',
#  'GSM6175782',
#  'GSM6175783',
#  'GSM6175784',
#  'GSM6175785',
#  'GSM6175786',
#  'GSM6175787',
#  'GSM6175788',
#  'GSM6175789']

# %%
ax = sns.clustermap(result, z_score=0, cmap = 'RdYlBu_r', figsize=(10,10))

# %%
from sanbomics.plots import volcano

# %%
res

# %%
res_hold = res.copy(deep=True)

# %%
res_hold['Gene-Id'] = res_hold.index

# %%
res_hold
# Out:
#                       baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# ENSTGUG00000008284  153.250189        0.061794  0.149819  0.412457  0.680004
# ENSTGUG00000003938   33.874202        0.497261  0.363909  1.366441  0.171801
# ENSTGUG00000011987  765.322113       -0.260081  0.116447 -2.233465  0.025518
# ENSTGUG00000017592   10.215077       -0.561700  0.514938 -1.090810  0.275357
# ENSTGUG00000009442  227.599403        0.047786  0.167182  0.285832  0.775007
# ...                        ...             ...       ...       ...       ...
# ENSTGUG00000005605    0.424525        1.742296  2.846117  0.612166  0.540428
# ENSTGUG00000018403  560.130458        0.080536  0.097607  0.825107  0.409311
# ENSTGUG00000014724    7.945951        0.434903  0.526703  0.825708  0.408970
# ENSTGUG00000006479  619.856201        0.171129  0.080062  2.137458  0.032561
# ENSTGUG00000017416  444.620825       -0.042794  0.713806 -0.059952  0.952194
#
# ...

# %%
volcano(res_hold, symbol='Gene-Id')
